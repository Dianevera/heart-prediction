# %%
from heartpredictions.Tree.utils import fit_and_predict

# %%
data_path = '../data/clean_data.csv'
save_directory = "current_accuracies/random_forest/random_forest_saves"

# %% [markdown]
# # Train and test

# %%
DEPTH = 5
NUM_TREES = 5

# %%
fit_and_predict(data_path, save_directory,
                 "Random Forest", NUM_TREES, max_depth=DEPTH)
# Out:
#              DEATH
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.7503762631692109
# sensitivity : 0.3675564681724846, specificity : 0.925705329153605, PPV : 0.6937984496124031, NPV : 0.7616713954088212
#
#
#
#
#              ANGINA
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.889701139539884
# sensitivity : 0.330718954248366, specificity : 0.9997426659804426, PPV : 0.9960629921259843, NPV : 0.8835569706618148
#
#
#
#
#              HOSPMI
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.9198021930767577
# sensitivity : 0.26997840172786175, specificity : 0.9916427889207259, PPV : 0.78125, NPV : 0.9247383656201291
#
#
#
#
#             MI_FCHD
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.8669103418619651
# sensitivity : 0.21208053691275167, specificity : 0.9918074756784434, PPV : 0.8315789473684211, NPV : 0.868415153553015
#
#
#
#
#              ANYCHD
#
#        Random forest fit
#
# ...
