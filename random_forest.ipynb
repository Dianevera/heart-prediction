# %%
import numpy as np

# %%
# %run random_forest_model.ipynb

# %%
data_path = 'data/clean_data.csv'

# %% [markdown]
# # Train and test

# %%
DEPTH = 5
NUM_TREES = 5

# %%
fit_and_predict(data_path, "Random Forest", NUM_TREES, max_depth=DEPTH)
# Out:
#              DEATH
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.7508062782197377
# sensitivity : 0.3586584531143053, specificity : 0.9304075235109718, PPV : 0.7024128686327078, NPV : 0.7600512163892446
#
#
#
#
#              ANGINA
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.8892711244893571
# sensitivity : 0.330718954248366, specificity : 0.9992279979413279, PPV : 0.98828125, NPV : 0.8835039817974971
#
#
#
#
#              HOSPMI
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.9195871855514943
# sensitivity : 0.2634989200863931, specificity : 0.9921203438395415, PPV : 0.7870967741935484, NPV : 0.9241548042704626
#
#
#
#
#             MI_FCHD
#
#        Random forest fit
#
#               Test
# accuracy ==> 0.8660503117609116
# sensitivity : 0.21610738255033557, specificity : 0.9900153609831029, PPV : 0.805, NPV : 0.8687935295439227
#
#
#
#
#              ANYCHD
#
#        Random forest fit
#
#               Test
# ...
